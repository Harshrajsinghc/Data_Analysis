# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('shopping_trends_updated.csv')
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.shape
# Out:
# (3900, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize =(5,5))
sns.distplot(x= df ['Review Rating'])
plt.show()

sns.distplot(x= df ['Previous Purchases'])
plt.show()

sns.distplot(x= df ['Age'])
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_6620\3635049123.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x= df ['Review Rating'])
# C:\Users\asus\AppData\Local\Temp\ipykernel_6620\3635049123.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
mylabels = ['Male', 'Female']
plt.pie(df['Gender'].value_counts()[:], labels = mylabels, autopct = '%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x2957fa941f0>,
# ...
#  [Text(-0.5894094953465412, 0.9287607048079368, 'Male'),
#   Text(0.5894094953465407, -0.9287607048079373, 'Female')],
#  [Text(-0.32149608837084065, 0.5065967480770565, '68.00'),
#   Text(0.32149608837084037, -0.5065967480770566, '32.00')])

# %%
df['Category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
mylabels = ['Clothing', 'Footwear', 'Outerwear', 'Accessories']
plt.pie(df['Category'].value_counts()[:], labels = mylabels, autopct = '%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x2957fbcde80>,
# ...
#  [Text(0.18781250770230096, 1.0838479883962386, 'Clothing'),
#   Text(-0.8718788619763391, -0.6706916206714112, 'Footwear'),
#   Text(0.5901575242400307, -0.9282855684447959, 'Outerwear'),
#   Text(1.0627474268695036, -0.2838448637587956, 'Accessories')],
#  [Text(0.10244318601943687, 0.5911898118524938, '44.54'),
#   Text(-0.4755702883507304, -0.36583179309349695, '31.79'),
#   Text(0.32190410413092574, -0.5063375827880704, '15.36'),
#   Text(0.5796804146560928, -0.1548244711411612, '8.31')])

# %%
df['Season'].unique()
# Out:
# array(['Winter', 'Spring', 'Summer', 'Fall'], dtype=object)

# %%
x= df['Item Purchased'].value_counts().index
y= df['Item Purchased'].value_counts()[:]
plt.figure(figsize =(20,10))
plt.bar(x,y)
# Out:
# <BarContainer object of 25 artists>

# %%
x= df['Subscription Status'].value_counts().index
y= df['Subscription Status'].value_counts()[:]
plt.figure(figsize =(5,5))
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
df['Frequency of Purchases'].unique()
# Out:
# array(['Fortnightly', 'Weekly', 'Annually', 'Quarterly', 'Bi-Weekly',
#        'Monthly', 'Every 3 Months'], dtype=object)

# %%
mylabels = ['Fortnightly', 'Weekly', 'Annually', 'Quarterly', 'Bi-Weekly',
       'Monthly', 'Every 3 Months']
plt.pie(df['Frequency of Purchases'].value_counts()[:], labels = mylabels, autopct = '%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x29509d942e0>,
# ...
#  [Text(0.9805091397664225, 0.498599866460582, 'Fortnightly'),
#   Text(0.185192785308572, 1.0842986822225937, 'Weekly'),
#   Text(-0.745867060783142, 0.8085062322819266, 'Annually'),
#   Text(-1.0970459268074513, -0.08056199150455776, 'Quarterly'),
#   Text(-0.631417910276884, -0.9007282734440909, 'Bi-Weekly'),
#   Text(0.28897804951565437, -1.0613631267846684, 'Monthly'),
#   Text(0.9979348326344176, -0.4627375820212976, 'Every 3 Months')],
#  [Text(0.5348231671453213, 0.2719635635239538, '14.97'),
#   Text(0.10101424653194835, 0.5914356448486874, '14.67'),
#   Text(-0.40683657860898653, 0.4410033994265054, '14.44'),
#   Text(-0.5983886873495189, -0.043942904457031494, '14.18'),
#   Text(-0.3444097692419367, -0.49130633096950405, '14.03'),
#   Text(0.15762439064490238, -0.5789253418825463, '13.90'),
#   Text(0.5443280905278641, -0.2524023174661623, '13.82')])

# %%
x= df['Season'].value_counts().index
y= df['Season'].value_counts()[:]
plt.figure(figsize =(5,5))
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>
